# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)
print(client.list_database_names())

db = client['Bible']
niv = db['NIV']

with open('/Users/seungchulha/Developer/Python/Bible/en_niv.json') as f:
    js = json.loads(f.read())
    
df = pd.read_json('/Users/seungchulha/Developer/Python/Bible/en_niv.json')

for i in range(len(df)):
    if df['book'][i] == "Genesis":
        book_id = "GEN"
    elif df['book'][i] == "Exodus":
        book_id = "EXO"
    elif df['book'][i] == "Leviticus":
        book_id = "LEV"
    elif df['book'][i] == "Numbers":
        book_id = "NUM"
    elif df['book'][i] == "Deuteronomy":
        book_id = "DEU"
    elif df['book'][i] == "Joshua":
        book_id = "JOS"
    elif df['book'][i] == "Judges":
        book_id = "JDG"
    elif df['book'][i] == "Ruth":
        book_id = "RUT"
    elif df['book'][i] == "1 Samuel":
        book_id = "1SA"
    elif df['book'][i] == "2 Samuel":
        book_id = "2SA"
    elif df['book'][i] == "1 Kings":
        book_id = "1KI"
    elif df['book'][i] == "2 Kings":
        book_id = "2KI"
    elif df['book'][i] == "1 Chronicles":
        book_id = "1CH"
    elif df['book'][i] == "2 Chronicles":
        book_id = "2CH"
    elif df['book'][i] == "Ezra":
        book_id = "EZR"
    elif df['book'][i] == "Nehemiah":
        book_id = "NEH"
    elif df['book'][i] == "Esther":
        book_id = "EST"
    elif df['book'][i] == "Job":
        book_id = "JOB"
    elif df['book'][i] == "Psalms":
        book_id = "PSA"
    elif df['book'][i] == "Proverbs":
        book_id = "PRO"
    elif df['book'][i] == "Ecclesiastes":
        book_id = "ECC"
    elif df['book'][i] == "Song of Songs":
        book_id = "SNG"
    elif df['book'][i] == "Isaiah":
        book_id = "ISA"
    elif df['book'][i] == "Jeremiah":
        book_id = "JER"
    elif df['book'][i] == "Lamentations":
        book_id = "LAM"
    elif df['book'][i] == "Ezekiel":
        book_id = "EZK"
    elif df['book'][i] == "Daniel":
        book_id = "DAN"
    elif df['book'][i] == "Hosea":
        book_id = "HOS"
    elif df['book'][i] == "Joel":
        book_id = "JOL"
    elif df['book'][i] == "Amos":
        book_id = "AMO"
    elif df['book'][i] == "Obadiah":
        book_id = "OBA"
    elif df['book'][i] == "Jonah":
        book_id = "JON"
    elif df['book'][i] == "Micah":
        book_id = "MIC"
    elif df['book'][i] == "Nahum":
        book_id = "NAM"
    elif df['book'][i] == "Habakkuk":
        book_id = "HAB"
    elif df['book'][i] == "Zephaniah":
        book_id = "ZEP"
    elif df['book'][i] == "Haggai":
        book_id = "HAG"
    elif df['book'][i] == "Zechariah":
        book_id = "ZEC"
    elif df['book'][i] == "Malachi":
        book_id = "MAL"
    elif df['book'][i] == "Matthew":
        book_id = "MAT"
    elif df['book'][i] == "Mark":
        book_id = "MRK"
    elif df['book'][i] == "Luke":
        book_id = "LUK"
    elif df['book'][i] == "John":
        book_id = "JHN"
    elif df['book'][i] == "Acts":
        book_id = "ACT"
    elif df['book'][i] == "Romans":
        book_id = "ROM"
    elif df['book'][i] == "1 Corinthians":
        book_id = "1CO"
    elif df['book'][i] == "2 Corinthians":
        book_id = "2CO"
    elif df['book'][i] == "Galatians":
        book_id = "GAL"
    elif df['book'][i] == "Ephesians":
        book_id = "EPH"
    elif df['book'][i] == "Philippians":
        book_id = "PHP"
    elif df['book'][i] == "Colossians":
        book_id = "COL"
    elif df['book'][i] == "1 Thessalonians":
        book_id = "1TH"
    elif df['book'][i] == "2 Thessalonians":
        book_id = "2TH"
    elif df['book'][i] == "1 Timothy":
        book_id = "1TI"
    elif df['book'][i] == "2 Timothy":
        book_id = "2TI"
    elif df['book'][i] == "Titus":
        book_id = "TIT"
    elif df['book'][i] == "Philemon":
        book_id = "PHI"
    elif df['book'][i] == "Hebrews":
        book_id = "HEB"
    elif df['book'][i] == "James":
        book_id = "JAS"
    elif df['book'][i] == "1 Peter":
        book_id = "1PE"
    elif df['book'][i] == "2 Peter":
        book_id = "2PE"
    elif df['book'][i] == "1 John":
        book_id = "1JN"
    elif df['book'][i] == "2 John":
        book_id = "2JN"
    elif df['book'][i] == "3 John":
        book_id = "2JN"
    elif df['book'][i] == "Jude":
        book_id = "JUD"
    elif df['book'][i] == "Revelation":
        book_id = "REV"

    chapter = int(str(df['chapter'][i]))
    verse = int(str(df['verse'][i]))  
    data = {
        "book_id": book_id,
        "book_name": df['book'][i],
        "chapter": chapter,
        "verse": verse,
        "text": df['word'][i]
    }
    niv.insert_one(data)

# %%
krv = db['KRV']

df = pd.read_json('/Users/seungchulha/Developer/Python/Bible/Bible-krv-master/요한계시록.json')

for i in range(len(df)):
    # i = 장
    for j in range(len(df['chapters'][i]['verses'])):
        # j 는 절
        verse = df['chapters'][i]['verses'][j]['verse']
        text = df['chapters'][i]['verses'][j]['text']

        data = {
            "book_id": "REV",
            "book_name": "Revelation",
            "chapter": i + 1,
            "verse": verse,
            "text": text
        }

        krv.insert_one(data)

# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)

db = client['Bible']

kjv = db["KJV"]

df = pd.read_json('/Users/seungchulha/Developer/Python/Bible/Bible-kjv-master/Revelation.json')

for i in range(len(df)):
    # i = 장
    for j in range(len(df['chapters'][i]['verses'])):
        # j 는 절
        verse = df['chapters'][i]['verses'][j]['verse']
        text = df['chapters'][i]['verses'][j]['text']

        data = {
            "book_id": "REV",
            "book_name": "Revelation",
            "chapter": i + 1,
            "verse": verse,
            "text": text
        }

        kjv.insert_one(data)

# %%
kjv.delete_many(
    {"book_name": {"$eq": "1Corinthians"}}
)

# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)

db = client['Bible']

nkjv = db["NKJV"]

df = pd.read_json('/Users/seungchulha/Developer/Python/Bible/NKJV.bible.json')

book_count = len(df['books'])

for i in range(book_count):
    book_name = df['books'][i]['name']

    if book_name == "Genesis":
        book_id = "GEN"
    elif book_name == "Exodus":
        book_id = "EXO"
    elif book_name == "Leviticus":
        book_id = "LEV"
    elif book_name == "Numbers":
        book_id = "NUM"
    elif book_name == "Deuteronomy":
        book_id = "DEU"
    elif book_name == "Joshua":
        book_id = "JOS"
    elif book_name == "Judges":
        book_id = "JDG"
    elif book_name == "Ruth":
        book_id = "RUT"
    elif book_name == "1 Samuel":
        book_id = "1SA"
    elif book_name == "2 Samuel":
        book_id = "2SA"
    elif book_name == "1 Kings":
        book_id = "1KI"
    elif book_name == "2 Kings":
        book_id = "2KI"
    elif book_name == "1 Chronicles":
        book_id = "1CH"
    elif book_name == "2 Chronicles":
        book_id = "2CH"
    elif book_name == "Ezra":
        book_id = "EZR"
    elif book_name == "Nehemiah":
        book_id = "NEH"
    elif book_name == "Esther":
        book_id = "EST"
    elif book_name == "Job":
        book_id = "JOB"
    elif book_name == "Psalms":
        book_id = "PSA"
    elif book_name == "Proverbs":
        book_id = "PRO"
    elif book_name == "Ecclesiastes":
        book_id = "ECC"
    elif book_name == "Song of Solomon":
        book_id = "SNG"
    elif book_name == "Isaiah":
        book_id = "ISA"
    elif book_name == "Jeremiah":
        book_id = "JER"
    elif book_name == "Lamentations":
        book_id = "LAM"
    elif book_name == "Ezekiel":
        book_id = "EZK"
    elif book_name == "Daniel":
        book_id = "DAN"
    elif book_name == "Hosea":
        book_id = "HOS"
    elif book_name == "Joel":
        book_id = "JOL"
    elif book_name == "Amos":
        book_id = "AMO"
    elif book_name == "Obadiah":
        book_id = "OBA"
    elif book_name == "Jonah":
        book_id = "JON"
    elif book_name == "Micah":
        book_id = "MIC"
    elif book_name == "Nahum":
        book_id = "NAM"
    elif book_name == "Habakkuk":
        book_id = "HAB"
    elif book_name == "Zephaniah":
        book_id = "ZEP"
    elif book_name == "Haggai":
        book_id = "HAG"
    elif book_name == "Zechariah":
        book_id = "ZEC"
    elif book_name == "Malachi":
        book_id = "MAL"
    elif book_name == "Matthew":
        book_id = "MAT"
    elif book_name == "Mark":
        book_id = "MRK"
    elif book_name == "Luke":
        book_id = "LUK"
    elif book_name == "John":
        book_id = "JHN"
    elif book_name == "Acts":
        book_id = "ACT"
    elif book_name == "Romans":
        book_id = "ROM"
    elif book_name == "1 Corinthians":
        book_id = "1CO"
    elif book_name == "2 Corinthians":
        book_id = "2CO"
    elif book_name == "Galatians":
        book_id = "GAL"
    elif book_name == "Ephesians":
        book_id = "EPH"
    elif book_name == "Philippians":
        book_id = "PHP"
    elif book_name == "Colossians":
        book_id = "COL"
    elif book_name == "1 Thessalonians":
        book_id = "1TH"
    elif book_name == "2 Thessalonians":
        book_id = "2TH"
    elif book_name == "1 Timothy":
        book_id = "1TI"
    elif book_name == "2 Timothy":
        book_id = "2TI"
    elif book_name == "Titus":
        book_id = "TIT"
    elif book_name == "Philemon":
        book_id = "PHI"
    elif book_name == "Hebrews":
        book_id = "HEB"
    elif book_name == "James":
        book_id = "JAS"
    elif book_name == "1 Peter":
        book_id = "1PE"
    elif book_name == "2 Peter":
        book_id = "2PE"
    elif book_name == "1 John":
        book_id = "1JN"
    elif book_name == "2 John":
        book_id = "2JN"
    elif book_name == "3 John":
        book_id = "2JN"
    elif book_name == "Jude":
        book_id = "JUD"
    elif book_name == "Revelation":
        book_id = "REV"

    chapter_count = len(df['books'][i]["chapters"])
    for j in range(chapter_count):
        verse_count = len(df['books'][i]["chapters"][j]['verses'])
        for k in range(verse_count):
            verse_text = df['books'][i]["chapters"][j]['verses'][k]['text']

            data = {
                "book_id": book_id,
                "book_name": book_name,
                "chapter": j + 1,
                "verse": k + 1,
                "text": verse_text
            }
            nkjv.insert_one(data)

# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)

db = client['Bible']

chinese = db["CHIUNL"]

df = pd.read_json('/Users/seungchulha/Developer/Python/Bible/bibles/ChiUnL.json')
df = df['books'][8:]

for i in range(len(df)): # i = booknumber
    book_id = f'book_id: {i+1}'
    book_name = f'book_name: {i+1}'
    for j in range(len(df[i])): # j = chapter
        chapter_number = f'chapter_number: {j+1}'
        for k in range(len(df[i][j])): # k = verse

            verse_text = df[i][j][k][0][0]

            data = {
                "book_id": book_id,
                "book_name": book_name,
                "chapter": j + 1,
                "verse": k + 1,
                "text": verse_text
            }

            chinese.insert_one(data)

# 순서가 책 권수 -> 장 -> 절

# %%
myquery1 = {"book_name": {"$eq": "book_name: 66"}}
newvalues1 = {"$set": {"book_name": "Revelation"}}

myquery2 = {"book_id": {"$eq": "book_id: 66"}}
newvalues2 = {"$set": {"book_id": "REV"}}

chinese.update_many(myquery1, newvalues1)
chinese.update_many(myquery2, newvalues2)

# %%
{book_name: "3 John"}

# %%
nkjv = db['NKJV']

myquery1 = {
    "book_name": {"$eq": "3 John"},
    "book_id": {"$eq": "2JN"},
    }
newvalues1 = {
    "$set": {"book_id": "3JN"}
    }
nkjv.update_many(myquery1, newvalues1)

# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)

db = client['Bible']

bookInfo = db['BookInfo']


data = {
            "english": "2 Chronicles",
            "chapter": 36,
            "korean": "역대하",
            "japanese": "歷代志下",
            "chinese": "歷代志下",
            "french": "2 CHRONIQUES",
            "spanish": "2 CRÓNICAS",
        }


bookInfo.insert_one(data)

# %%
import json, pandas as pd
from pymongo import MongoClient

mongodb_URI = "mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(mongodb_URI)

db = client['Bible']

bookInfo = db['BookInfo']

df = pd.read_excel('/Users/seungchulha/Developer/Python/Bible/성경.xlsx')

for i in range(len(df)):
    korean = df['korean'][i]
    english = df['english'][i]
    japanese = df['japan'][i]
    french = df['french'][i]
    espanol = df['espanol'][i]
    chinese = df['china'][i]
    german = df['german'][i]
    russian = df['russian'][i]
    greek = df['greek'][i]
    hindi = df['hindi'][i]
    portuguese = df['portuguese'][i]
    chapter = int(df['chapter'][i])

    data = {
        'korean': korean,
        'english': english,
        'japanese': japanese,
        'french': french,
        'spanish': espanol,
        'chinese': chinese,
        'german': german,
        'russian': russian,
        'greek': greek,
        'hindi': hindi,
        'portuguese': portuguese,
        'chapter': chapter
    }
    bookInfo.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Cell In[23], line 41
#      25 chapter = df['chapter'][i]
#      27 data = {
#      28     'korean': korean,
#      29     'english': english,
#    (...)
#      39     'chapter': chapter
#      40 }
# ---> 41 bookInfo.insert_one(data)
#
# File /usr/local/lib/python3.10/site-packages/pymongo/collection.py:628, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     624     document["_id"] = ObjectId()  # type: ignore[index]
#     626 write_concern = self._write_concern_for(session)
#     627 return InsertOneResult(
# --> 628     self._insert_one(
#     629         document,
#     630         ordered=True,
#     631         write_concern=write_concern,
#     632         op_id=None,
#     633         bypass_doc_val=bypass_document_validation,
#     634         session=session,
# ...

# %%
# !pip3 install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 5.3 MB/s eta 0:00:00a 0:00:01
# ...
